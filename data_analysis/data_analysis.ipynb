# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import seaborn as sns

# %%
itemCF = [0.3143487858719647, 0.3143487858719647, 0.3139072847682119, 0.3130242825607064, 0.3090507726269316, 0.2997792494481236, 0.2785871964679912, 0.23443708609271524, 0.16247240618101544, 0.08653421633554084]
# item2vec = [0.43611111111111117, 0.43611111111111117, 0.43472222222222223, 0.4305555555555556, 0.4166666666666667, 0.3819444444444444, 0.30972222222222223, 0.18981481481481483, 0.09675925925925927, 0.033796296296296297]
LFM = [0.04088397790055249, 0.04077348066298343, 0.0407182320441989, 0.04055248618784531, 0.04022099447513812, 0.03968692449355433, 0.038587213891081294, 0.036505524861878455, 0.03378759975445058, 0.03087292817679558]
NCF_new = [0.22838427947598255, 0.24279475982532753, 0.24759825327510918, 0.23624454148471616, 0.23231441048034937, 0.22227074235807862, 0.2314410480349345, 0.20786026200873364, 0.18384279475982535, 0.11655629139072847]
NCF_old = [0.18340611353711792, 0.17292576419213973, 0.16331877729257643, 0.1646288209606987, 0.15938864628820962, 0.14890829694323146, 0.1427947598253275, 0.07554585152838426, 0.03449781659388646, 0.011920529801324504]
x_data = [i for i in range(10)]
itemCF, = plt.plot(x_data, itemCF, color = 'blue')
# item2vec, = plt.plot(x_data, item2vec, color = 'red')
LFM, = plt.plot(x_data, LFM, color = 'green')
NCF_new, = plt.plot(x_data, NCF_new, color = 'black')
NCF_old, = plt.plot(x_data, NCF_old, color = 'yellow')
plt.legend([itemCF, LFM, NCF_new, NCF_old], ['itemCF', 'LFM', 'NCF_new', 'NCF_old'])
plt.xlabel("rating")
plt.ylabel("precision")
plt.savefig("precision.jpg")
plt.show()

# %%
loss = [0.2531039550030212, 0.11041744155612015, 0.07096146894889198, 0.05377859725110562, 
 0.044622671564257956, 0.03835699780066107, 0.03437716923451091, 0.03128412372324891, 
 0.029315666233017203, 0.02714866978027847, 0.026185558800014636, 0.024968316463586878, 
 0.02423919501151467, 0.023447535327403433, 0.02303745230186406, 0.02212490043505691, 
 0.021862888989923633, 0.02152913511073426, 0.02089601559603607, 0.020792764879287655, 
 0.020678016592359946, 0.020766532496323514, 0.019994376724562054, 0.019936440221913408, 
 0.02016734930261562, 0.019860407425247348, 0.019492902299603793, 0.02001899021848884, 
 0.019420548701896394, 0.019322245990735495]
x_data = [i for i in range(30)]
plt.plot(x_data, loss)
plt.xlabel("iteration")
plt.ylabel("loss")
plt.savefig('LFM_loss.jpg')
plt.show()

# %%
MLP = [0.37157237279274086, 0.2477973664976635, 0.2396407093030489, 0.2336932306129657, 
       0.22844408198990465, 0.22506443206532445, 0.22338746511196905, 0.22189184373395873, 
       0.2209419065935181, 0.22026824099416395, 0.21958490476614112, 0.21896676738035528,
       0.21835950474771176, 0.21774004235018618, 0.21702001713480767, 0.21648280844791526, 
       0.21591884981778534, 0.21541594328782063, 0.21482789030686927, 0.2144672526529204,
       0.21395322281041956, 0.21353701458615412, 0.21312855110514753, 0.21258850201131468, 
       0.2123978354830199, 0.21200651642936727, 0.21180320479757006, 0.2116168748476417, 
       0.21132563668603754, 0.2107019572112571]
GMF = [0.6627772962837889, 0.5444680874394379, 0.4088423880617359, 0.31827214697048356,
       0.271397169003045, 0.24677128124387834, 0.2321793955900094, 0.22263663271552248, 
       0.21607857659270646, 0.2114692259593576, 0.2082077394281782, 0.20589140191315536, 
       0.20423908490324352, 0.2030339018695941, 0.20213088742181848, 0.20141624662035681,
       0.20084801571605548, 0.20035086580073772, 0.19992971045175215, 0.19953214218182644, 
       0.1991626209857171, 0.19880934144734655, 0.19845281637405582, 0.19807849622585005,
       0.19768839690914838, 0.1972546243074231, 0.19677321302774048, 0.196229062260097,
       0.1956081374573834, 0.19487208500656483]
NCF = [0.28302387084609776, 0.20581690063650682, 0.20081167821614707, 0.19696746076529778, 
       0.1937980191992624, 0.19132998512745486, 0.18950045616443864, 0.18814022814142903, 
       0.1869868514964358, 0.18614997344204767, 0.18535737489642343, 0.1846923864359566,
       0.1839295286139582, 0.18318382728129004, 0.18258232327564936, 0.18168775263074854,
       0.18088796918414554, 0.18010557793393908, 0.1792128094601563, 0.17829871617230236,
       0.17731331386696508, 0.17639257356688617, 0.1752810421305158, 0.1743890779303415,
       0.17331523802974963, 0.17233755144962046, 0.1713309818046621, 0.17037220153940885,
       0.1694780224162868, 0.16860507391560375]
x_data = [i for i in range(30)]
mlp, = plt.plot(x_data, MLP, color = 'blue')
gmf, = plt.plot(x_data, GMF, color = 'red')
ncf, = plt.plot(x_data, NCF, color = 'black')
plt.xlabel("iteration")
plt.ylabel("loss")
plt.legend([mlp, gmf, ncf], ["MLP", "GMF", "NCF"])
plt.savefig("old_NCF_loss.jpg")
plt.show()

# %%
df = pd.read_csv("~/Data/clean_rating4.csv")
plt.figure()
sns.distplot(df['rating'], kde = False)
plt.savefig("rating_distribution.jpg")
plt.show()

# %%
animes = pd.read_csv("~/Data/anime2.csv").dropna()
scalar = lambda x: (x - np.min(x)) / (np.max(x) - np.min(x))
animes["rating_norm"] = animes[["rating"]].apply(scalar)
animes["members_norm"] = animes[["members"]].apply(scalar)
animes["weight"] = 0.6 * animes["rating_norm"] + 0.4 * animes["members_norm"]


plt.figure(figsize = (18,6))
plt.subplot(131)
sns.distplot(animes["rating"])

plt.subplot(132)
sns.distplot(animes["members"])

plt.subplot(133)
sns.distplot(animes["weight"])
plt.savefig("all_fig.jpg")
plt.show()

# %%
sns.distplot(animes["members"])
plt.savefig("member_distribution.jpg")
plt.show()

# %%
scalar = lambda x: (x - np.min(x)) / (np.max(x) - np.min(x))
animes["rating_norm"] = animes[["rating"]].apply(scalar)
animes["members_norm"] = animes[["members"]].apply(scalar)
animes["weight"] = 0.6 * animes["rating_norm"] + 0.4 * animes["members_norm"]
sns.distplot(animes["weight"])
plt.savefig("weight_distribution.jpg")
plt.show()

# %%
from scipy import stats
animes = pd.read_csv("~/Data/anime2.csv").dropna()
scalar = lambda x: (x - np.min(x)) / (np.max(x) - np.min(x))
animes["rating_norm"] = animes[["rating"]].apply(scalar)
animes["members_norm"] = animes[["members"]].apply(scalar)
animes["weight"] = 0.6 * animes["rating_norm"] + 0.4 * animes["members_norm"]

fig = plt.figure()
res = stats.probplot(animes["weight"], plot = plt)
# res = stats.probplot(df2['rating'], plot = plt)
plt.savefig("probplot_weight.jpg")
plt.show()

# %%
re = [0.8400000000000001, 0.8400000000000001, 0.8200000000000001, 0.8200000000000001, 0.8200000000000001, 0.8000000000000002, 0.76, 0.65, 0.43000000000000005, 0.15]
ra = [0.04, 0.04, 0.04, 0.04, 0.04, 0.02, 0.02, 0.02, 0.01, 0.01]
ho = [0.77, 0.77, 0.75, 0.75, 0.75, 0.73, 0.6699999999999999, 0.55, 0.32999999999999996, 0.09999999999999999]
x = [i for i in range(10)]
plt.figure()
re, = plt.plot(x, re, color = 'blue')
ho, = plt.plot(x, ho, color = 'red')
ra, = plt.plot(x, ra, color = 'black')
plt.legend([re, ho, ra], ["TF-IDF", "Hot", "Random"])
plt.xlabel('rating')
plt.ylabel('precision')
plt.savefig("cold_start_precision.jpg")
plt.show()

# %%
ndcg_ncf_new = [0.15657179995024778, 0.16395829618549218, 0.15354860007950705, 0.1616809232922874, 0.14990870794238562, 0.14959011189410462, 0.15131346213302319, 0.13914666960037497, 0.11062696842731777, 0.0737071977810111]
ndcg_ncf_old = [0.11494508007260133, 0.11098339065382137, 0.10887148086832325, 0.10833260250648793, 0.10359681936633955, 0.09869827935021672, 0.0847561131575149, 0.04675112571136788, 0.02261771035424707, 0.009556181976864099]
ndcg_lfm = [0.014834511685310595, 0.014716975242358885, 0.014675898018339085, 0.014593743570299487, 0.014328689191308539, 0.013754242107075702, 0.012451751073086093, 0.00920592559239942, 0.005519314722759233, 0.002572878816357417]
x = [i for i in range(10)]
plt.figure()
plt.plot(x, ndcg_ncf_new, c = 'red')
plt.plot(x, ndcg_ncf_old, c = 'blue')
plt.plot(x, ndcg_lfm, c = 'green')
plt.show()
