# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import seaborn as sns

# %%
itemCF = [1.0, 0.9962561157200595, 0.9911933631142311, 0.9838332269729845, 0.9675388215273345, 0.9372899383109978, 0.8802807913209957, 0.7497553711976175, 0.5318868325888109, 0.277898319506488]
# item2vec = [0.43611111111111117, 0.43611111111111117, 0.43472222222222223, 0.4305555555555556, 0.4166666666666667, 0.3819444444444444, 0.30972222222222223, 0.18981481481481483, 0.09675925925925927, 0.033796296296296297]
LFM = [1.0, 0.9927674962773878, 0.9833652414379922, 0.9658796000850883, 0.9320144650074453, 0.865049989363965, 0.7365241437991916, 0.48810891299723463, 0.23731121038077002, 0.08959795788130184]
NCF_new = [1.0, 0.9985534992554778, 0.9962561157200597, 0.9943841735800895, 0.9899595830674325, 0.9792810040416934, 0.950393533290789, 0.859902148479047, 0.6607104871303978, 0.3569027866411402]
NCF_old = [1.0, 0.9947245266964475, 0.9880450967879175, 0.9755371197617528, 0.9461391193363115, 0.8849181025313763, 0.7511167836630505, 0.48942778132312276, 0.22186768772601573, 0.08487555839183153]
BPR = [1.0, 0.9069559668155712, 0.7984258668368431, 0.6593065305254201, 0.44981918740693466, 0.2057009146990002, 0.05207402680280791, 0.011231652839821315, 0.005360561582641991, 0.0043395022335673255]
x_data = [i for i in range(10)]
itemCF, = plt.plot(x_data, itemCF, color = 'blue')
# item2vec, = plt.plot(x_data, item2vec, color = 'red')
LFM, = plt.plot(x_data, LFM, color = 'red')
NCF_new, = plt.plot(x_data, NCF_new, color = 'black')
NCF_old, = plt.plot(x_data, NCF_old, color = 'yellow')
BPR, = plt.plot(x_data, BPR, color = "green")
plt.legend([itemCF, LFM, NCF_new, NCF_old, BPR], ['itemCF', 'LFM', 'NCF_new', 'NCF_old', "BPR"])
plt.xlabel("rating")
plt.ylabel("precision")
plt.savefig("precision.jpg")
plt.show()

# %%
loss = [0.18030898087022273, 0.10848601644591498, 0.0709805096193708, 0.0527580640736663, 
        0.043247173574194504, 0.03734086560867708, 0.0335774526962298, 0.030060293921356455, 
        0.028271445582630114, 0.026635097122290084, 0.025345283139165883, 0.024212969759301893, 
        0.023434833138787258, 0.02255711258725834, 0.0223114990172638, 0.02200024780382737, 
        0.020914185943746003, 0.020875434378049923, 0.02028482928001763, 0.020124117336000058, 
        0.01994991355278006, 0.020115463519858216, 0.019422970193320926, 0.019307259660603076,
        0.01928419077902894, 0.018771222958243548, 0.018768842033407184, 0.01869189932446103, 
        0.019206361817647653, 0.019255725324471465]
x_data = [i for i in range(30)]
plt.plot(x_data, loss)
plt.xlabel("iteration")
plt.ylabel("loss")
plt.savefig('LFM_loss.jpg')
plt.show()

# %%
precision = [1.0, 0.9927674962773878, 0.9833652414379922, 0.9658796000850883, 0.9320144650074453, 0.865049989363965, 0.7365241437991916, 0.48810891299723463, 0.23731121038077002, 0.08959795788130184]
x_data = [i for i in range(10)]
plt.plot(x_data, precision)
plt.xlabel("iteration")
plt.ylabel("precision")
plt.savefig("LFM_precision.jpg")
plt.show()

# %%
MLP = [0.05749154522469858, 0.05117393039712092, 0.0386332842952958, 0.026603427658811574, 
       0.022893851486648003, 0.02099883337164434, 0.02000373156695831, 0.019396662019284035, 
       0.019004528319872007, 0.018671167889473643, 0.018429065418497818, 0.018220386218007017, 
ncf = [0.601068966365555, 0.3321887317791726, 0.26265044898084067, 0.23197681348300675, 
       0.21485859074638886, 0.20469166963424498, 0.1979629316086908, 0.19312459042350066, 
       0.18937522439123358, 0.18608199977180334, 0.18329068477292662, 0.18075901837024874, 
       0.17879824508162379, 0.17667025371083936, 0.17502753558089432, 0.17328596288718065, 
       0.1715969898747009, 0.1700373423909678, 0.16864589675537592, 0.16769526910434648, 
       0.16660841497981432, 0.16601219796439975, 0.1651881731250911, 0.16470952728419627, 
       0.16400857984440997, 0.16351805647600046, 0.16292512885575156, 0.1625200913369077, 
       0.16196804483538693, 0.16149699994661276]

x_data = [i for i in range(30)]
mlp, = plt.plot(x_data, mlp, color = 'blue')
gmf, = plt.plot(x_data, gmf, color = 'red')
ncf, = plt.plot(x_data, ncf, color = 'black')
plt.xlabel("iteration")
plt.ylabel("loss")
plt.legend([mlp, gmf, ncf], ["MLP", "GMF", "NCF"])
plt.savefig("Old_NCF_loss.jpg")
plt.show()

# %%
ncf = [0.11061476281642203, 0.12584556477345246, 0.137034673473729, 0.16656030631780472, 0.21706019995745587, 0.2866624122527122, 0.28487555839183154, 0.3064454371410338, 0.2880663688576899, 0.27326100829610717, 0.29227823867262287, 0.3206551797489896, 0.31414592639863864, 0.2947032546266752, 0.3184428844926611, 0.2825356307168688, 0.32992980216975115, 0.3257604764943629, 0.3071261433737503, 0.311210380770049, 0.32005956179536266, 0.31857051691129545, 0.33095086151882575, 0.3419697936609232, 0.35171240161667733, 0.33746011486917676, 0.32193150393533293, 0.3361412465432887, 0.3358434375664753, 0.3215911508189747]
gmf = [0.10550946607104872, 0.1095086151882578, 0.17800467985534993, 0.24148053605615827, 0.27368644969155503, 0.2849181025313763, 0.2597745160604127, 0.28564135290363757, 0.28274835141459265, 0.28325888108913, 0.2907466496490108, 0.29793660923207826, 0.29814932992980214, 0.2972984471389066, 0.30495639225696664, 0.3055520102105935, 0.3152095298872581, 0.325164858540736, 0.31410338225909384, 0.3324824505424378, 0.3354605403105722, 0.3317166560306318, 0.34533078068496065, 0.344692618591789, 0.34533078068496065, 0.346607104871304, 0.3509891512444161, 0.34733035524356526, 0.3615400978515209, 0.3594128908742821]
mlp = [0.1269091682620719, 0.12137843012125078, 0.2796000850882791, 0.16953839608593915, 0.18902361199744735, 0.23148266326313552, 0.2744947883429058, 0.2589661774090619, 0.2619868113167411, 0.2677302701552861, 0.274452244203361, 0.3084450116996384, 0.27343118485428636, 0.30104233141884706, 0.298191874069347, 0.29942565411614547, 0.31346522016592215, 0.2853435439268241, 0.2835566900659434, 0.2902361199744735, 0.3221442246330568, 0.3013401403956605, 0.3116358221654967, 0.3124016166773027, 0.3184854286322059, 0.3090406296532653, 0.3265688151457137, 0.31895341416719847, 0.32027228249308654, 0.3105722186768773]
x = [i for i in range(30)]
plt.figure()
n, = plt.plot(x, ncf, c = 'red')
g, = plt.plot(x, gmf, c = 'blue')
m, = plt.plot(x, mlp, c = 'green')
plt.legend([n, g, m], ["NCF", "GMF", "MLP"])
plt.xlabel("iteration")
plt.ylabel("precision")
plt.savefig("precision_iteration.jpg")
plt.show()

# %%
df = pd.read_csv("~/Data/clean_rating4.csv")
plt.figure()
sns.distplot(df['rating'], kde = False)
plt.savefig("rating_distribution.jpg")
plt.show()

# %%
animes = pd.read_csv("~/Data/anime2.csv").dropna()
scalar = lambda x: (x - np.min(x)) / (np.max(x) - np.min(x))
animes["rating_norm"] = animes[["rating"]].apply(scalar)
animes["members_norm"] = animes[["members"]].apply(scalar)
animes["weight"] = 0.6 * animes["rating_norm"] + 0.4 * animes["members_norm"]


plt.figure(figsize = (18,6))
plt.subplot(131)
sns.distplot(animes["rating"])

plt.subplot(132)
sns.distplot(animes["members"])

plt.subplot(133)
sns.distplot(animes["weight"])
plt.savefig("all_fig.jpg")
plt.show()

# %%
sns.distplot(animes["members"])
plt.savefig("member_distribution.jpg")
plt.show()

# %%
scalar = lambda x: (x - np.min(x)) / (np.max(x) - np.min(x))
animes["rating_norm"] = animes[["rating"]].apply(scalar)
animes["members_norm"] = animes[["members"]].apply(scalar)
animes["weight"] = 0.6 * animes["rating_norm"] + 0.4 * animes["members_norm"]
sns.distplot(animes["weight"])
plt.savefig("weight_distribution.jpg")
plt.show()

# %%
from scipy import stats
animes = pd.read_csv("~/Data/anime2.csv").dropna()
scalar = lambda x: (x - np.min(x)) / (np.max(x) - np.min(x))
animes["rating_norm"] = animes[["rating"]].apply(scalar)
animes["members_norm"] = animes[["members"]].apply(scalar)
animes["weight"] = 0.6 * animes["rating_norm"] + 0.4 * animes["members_norm"]

fig = plt.figure()
res = stats.probplot(animes["weight"], plot = plt)
# res = stats.probplot(df2['rating'], plot = plt)
plt.savefig("probplot_weight.jpg")
plt.show()

# %%
re = [0.8400000000000001, 0.8400000000000001, 0.8200000000000001, 0.8200000000000001, 0.8200000000000001, 0.8000000000000002, 0.76, 0.65, 0.43000000000000005, 0.15]
ra = [0.04, 0.04, 0.04, 0.04, 0.04, 0.02, 0.02, 0.02, 0.01, 0.01]
ho = [0.77, 0.77, 0.75, 0.75, 0.75, 0.73, 0.6699999999999999, 0.55, 0.32999999999999996, 0.09999999999999999]
x = [i for i in range(10)]
plt.figure()
re, = plt.plot(x, re, color = 'blue')
ho, = plt.plot(x, ho, color = 'red')
ra, = plt.plot(x, ra, color = 'black')
plt.legend([re, ho, ra], ["TF-IDF", "Hot", "Random"])
plt.xlabel('rating')
plt.ylabel('precision')
plt.savefig("cold_start_precision.jpg")
plt.show()

# %%
ndcg_ncf_new = [0.14257592658586676, 0.13182745369215734, 0.13582495771583644, 0.12993162571582242, 0.13896901269577408, 0.14059730459631595, 0.13594528926253038, 0.1282850630061106, 0.10139770954220602, 0.07282386054740611]
ndcg_ncf_old = [0.12291302136579671, 0.12040168688531584, 0.1269895291803799, 0.11553488698849355, 0.11674780244919446, 0.1066306828890327, 0.08922114520123008, 0.05873569861841453, 0.02193337709638735, 0.009395865907325563]
ndcg_lfm = [0.014834511685310595, 0.014716975242358885, 0.014675898018339085, 0.014593743570299487, 0.014328689191308539, 0.013754242107075702, 0.012451751073086093, 0.00920592559239942, 0.005519314722759233, 0.002572878816357417]
ndcg_itemcf = [0.1891258420383167, 0.1891258420383167, 0.18891888054406006, 0.18850495755554675, 0.18583034508734766, 0.1796324749004105, 0.1680489537635854, 0.14193992356121823, 0.09824439482515987, 0.05346556795362338]
x = [i for i in range(10)]
plt.figure()
ncf_new, = plt.plot(x, ndcg_ncf_new, c = 'red')
ncf_old, = plt.plot(x, ndcg_ncf_old, c = 'blue')
lfm, = plt.plot(x, ndcg_lfm, c = 'green')
itemcf, = plt.plot(x, ndcg_itemcf, c = 'black')
plt.legend([ncf_new, ncf_old, lfm, itemcf], ["NCF_new", "NCF_old", "LFM", "itemCF"])
plt.xlabel("rating")
plt.ylabel("NCDG")
plt.savefig("NDCG.jpg")
plt.show()

# %%
mlp = [0.11416670043698153, 0.13102073473143871, 0.14647406420903403, 0.18569976497044263, 
       0.22853720863468913, 0.26267799901507544, 0.26839072927296237, 0.2608635688467133,
       0.29467951094596784, 0.3083408997725696, 0.3147443654825022, 0.31328975690353683,
       0.27667862456223347, 0.31950959827804687, 0.33859722008787624, 0.340316927559607,
       0.3337125784192878, 0.35066422495821775, 0.3697316632893633, 0.3515098426613481,
       0.351568461153884, 0.3715991001609451, 0.35598373583685516, 0.35742029392557406,
       0.3386118696190623, 0.34999294102880874]

gmf = [0.1083736079598392, 0.12372099806799183, 0.1749812587759188, 0.29686869997246457,
       0.28804663768632394, 0.3245286159889664, 0.34659698559820523, 0.32642255150597616,
       0.3261783657764191, 0.3483909156940536, 0.33815188721635947, 0.32856573375561965,
       0.3577474572775056, 0.3632675011403505, 0.3655436622669645, 0.36422922598779744,
       0.37347621199505837, 0.39099876281685153, 0.3926084472608566, 0.39228256156395386,
       0.3878218386394425, 0.40365398568777217, 0.4205494745082642, 0.41329306775008157,
       0.4013379898832819, 0.4221135068522857]

ncf = [0.1125601820379165, 0.14232936712459218, 0.1366024080123582, 0.2190858872993334, 
       0.24939138250593942, 0.23554356988597444, 0.3195003359562401, 0.3306582865922804,
       0.257983818313154, 0.3445179453449088, 0.3663647417193335, 0.35286875706472803,
       0.3790730190715391, 0.2850265375318349, 0.27931583478899347, 0.349670131557396,
       0.370747689822556, 0.39353886532536336, 0.3845239159356938, 0.3604536020241303,
       0.3159518209221122, 0.36633721106483264, 0.38566974866751624, 0.38615954914941725,
       0.376994659205969, 0.3753126971706791]

x = [i for i in range(26)]
MLP, = plt.plot(x, mlp, c = 'blue')
GMF, = plt.plot(x, gmf, c = 'red')
NCF, = plt.plot(x, ncf, c = 'green')
plt.legend([MLP, GMF, NCF], ['MLP', "GMF", "NCF"])
plt.xlabel("iteration")
plt.ylabel("NDCG")
plt.savefig("ncf_ndcg.jpg")
plt.show()

# %%
bpr_loss = [33.288747597236984,0.0015058380634647877,0.0011498136252565117,0.0012791689498957261,
            0.0012105081835363666,0.0009266369508736299,0.0008918527281764662,0.0005438231723212497,
            0.00043889454432896206,0.0002939776040986635,0.00019839053043370136,0.00013277045609167936,
            0.00013184452813769142,5.71275541561136e-05,4.364641085358039e-05,3.4593921313937913e-05,
            1.7141461627096192e-05,1.7754453824553298e-05,8.77377278056628e-06,6.5206203232172496e-06,
            3.6710467285070663e-06,2.128887132392407e-06,9.958860288136463e-07,1.6032993879910645e-06,8.65328022175365e-07,
            2.3681753083622318e-07,1.3551144126941414e-07,1.6156573932258565e-07,1.2910704387713482e-07,
            3.9445356009880554e-08]
x = [i for i in range(30)]
plt.plot(x, bpr_loss, c = 'blue')
plt.xlabel("iteration")
plt.ylabel("loss")
plt.savefig("bpr_loss.jpg")
plt.show()
